# %% [markdown]
# <a href="https://colab.research.google.com/github/mlvlab/vision-tutorial/blob/master/02_1_Template_matching.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
#from google.colab import files
#uploaded = files.upload()

# %%
# !wget -O original https://raw.githubusercontent.com/MLman/computer-vision-AAA534/master/02-edge/mario.jpg
# !wget -O template https://raw.githubusercontent.com/MLman/computer-vision-AAA534/master/02-edge/mario_coin.jpg
# Out:
# --2019-10-01 00:00:32--  https://raw.githubusercontent.com/MLman/computer-vision-AAA534/master/02-edge/mario.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13726 (13K) [image/jpeg]
# Saving to: ‘original’
#
# original            100%[===================>]  13.40K  --.-KB/s    in 0.007s
#
# 2019-10-01 00:00:37 (1.89 MB/s) - ‘original’ saved [13726/13726]
#
# --2019-10-01 00:00:38--  https://raw.githubusercontent.com/MLman/computer-vision-AAA534/master/02-edge/mario_coin.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
img_rgb = cv2.imread('original')
img_rgb.shape
# Out:
# (224, 256, 3)

# %%
plt.imshow(img_rgb)

# %%
original = cv2.cvtColor(img_rgb, cv2.COLOR_BGR2RGB) 
original.shape
# Out:
# (224, 256, 3)

# %%
plt.imshow(original)

# %%
template = cv2.imread('template')
template = cv2.cvtColor(template, cv2.COLOR_BGR2RGB) 
r, c, _ = template.shape
template.shape
# Out:
# (19, 13, 3)

# %%
plt.figure(figsize = (1,1))
plt.imshow(template)
plt.show()

# %%
res = cv2.matchTemplate(original, template, cv2.TM_CCOEFF_NORMED)

# %%
plt.imshow(res)
plt.show()

# %%
threshold = 0.8
loc = np.where(res >= threshold) # (row, column)
for pt in zip(*loc[::-1]): # (column, row)
    cv2.rectangle(original, (pt[0], pt[1]), (pt[0] + c, pt[1] + r), (0,255,0), 2)

# %%
plt.imshow(original)
plt.show()
